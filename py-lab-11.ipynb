# %% [markdown]
# # Lab 11
#
# **Lecture**: Deep Learning (Prof. Dr. David Rügamer, Emanuel Sommer)
#
# ## Imports

# %%
from math import ceil
from typing import List, Tuple

import matplotlib.pyplot as plt
import torch
from matplotlib_inline.backend_inline import set_matplotlib_formats
from torch import nn, Tensor
from torch.distributions import Normal
from torch.optim import Adam, Optimizer
from torch.utils.data import DataLoader
from torchvision.datasets import MNIST
from torchvision.transforms import ToTensor
from torchvision.utils import make_grid
from torchsummary import summary

set_matplotlib_formats('png', 'pdf')

# %% [markdown]
# # Exercise 1
#
# In this exercise, we will implement a denoising autoencoder (DAE). We will use the MNIST dataset for this task. The autoencoder will be trained on noisy images and should be able to remove the noise from the images.

# %%
train_x = MNIST(root='.data', download=True, transform=ToTensor())

# %% [markdown]
# Let's first construct a basic fully connected autoencoder.

# %%
class AE(nn.Module):
    def __init__(self):
        super(AE, self).__init__()
        self.encoder = nn.Sequential(
            nn.Linear(28*28, 128),
            nn.ReLU(),
            nn.Linear(128, 64),
            nn.ReLU()
        )
        
        self.decoder = nn.Sequential(
            nn.Linear(64, 128),
            nn.ReLU(),
            nn.Linear(128, 28*28),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

# %% [markdown]
# Let's define the denoising autoencoder class which will add Gaussian noise to the input images before passing them through the autoencoder.

# %%
class DAE(nn.Module):
    def __init__(self, autoencoder):
        super(DAE, self).__init__()
        self.autoencoder = autoencoder

    def forward(self, x, noise_factor=0.5):
        x_noisy = x + noise_factor * torch.randn_like(x)
        x_recon = self.autoencoder(x_noisy)
        return x_recon

# %% [markdown]
# First let's look at some original images and their noisy versions with varying noise factors.

# %%
# plot original and noisy images
noise_fcts = [0.0, 0.1, 0.5, 1.0]
fig, axs = plt.subplots(2, len(noise_fcts), figsize=(12, 4))
for i, noise_fct in enumerate(noise_fcts):
    for ax, x in zip(axs[:, i], train_x):
        x = x[0]
        x_noisy = x + noise_fct * torch.randn_like(x)
        ax.imshow(x_noisy.squeeze().numpy(), cmap='gray')
    axs[0, i].set_title(f'Noise factor {noise_fct}')
    axs[0, i].set_xticks([])
    axs[0, i].set_yticks([])
    axs[1, i].set_xticks([])
    axs[1, i].set_yticks([])

# %% [markdown]
# Let's write a simple training loop to train the DAE on the MNIST dataset.

# %%
autoencoder = AE()
dae = DAE(autoencoder)

device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
dae = dae.to(device)

optimizer = torch.optim.Adam(dae.parameters(), lr=0.001)
criterion = (
    nn.MSELoss()
)
for epoch in range(2):
    for i, (images, _) in enumerate(train_x):
        # flatten the images
        images = images.view(-1, 28*28).to(device)
        images_recon = dae(images, noise_factor=0.5)
        loss = criterion(images_recon, images)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item():.4f}')
# Out:
# Epoch 1, Loss: 0.0393
# Epoch 2, Loss: 0.0435

# %%
summary(dae, (28*28,))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Linear-1                  [-1, 128]         100,480
#               ReLU-2                  [-1, 128]               0
#             Linear-3                   [-1, 64]           8,256
#               ReLU-4                   [-1, 64]               0
#             Linear-5                  [-1, 128]           8,320
#               ReLU-6                  [-1, 128]               0
#             Linear-7                  [-1, 784]         101,136
#            Sigmoid-8                  [-1, 784]               0
#                 AE-9                  [-1, 784]               0
# ================================================================
# Total params: 218,192
# Trainable params: 218,192
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.02
# Params size (MB): 0.83
# Estimated Total Size (MB): 0.86
# ----------------------------------------------------------------

# %% [markdown]
# The loss decreased during training, which is a good sign. Let's now visualize the original images, noisy images, and the denoised images.

# %%
# plot original, noisy and reconstructed images

fig, axs = plt.subplots(3, 3, figsize=(6, 6))
for i, (images, _) in enumerate(train_x):
    images = images.view(-1, 28*28).to(device)
    noisy_imges = images + 0.5 * torch.randn_like(images)
    recon_images = dae.autoencoder(images)
    for ax, img in zip(axs[i, :], [images, noisy_imges, recon_images]):
        ax.imshow(img.view(28, 28).cpu().detach().numpy(), cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
    if i == 2:
        break

# %% [markdown]
# Let's try to be much more parameter efficient by using a convolutional autoencoder.

# %%
class CAE(nn.Module):
    def __init__(self):
        super(CAE, self).__init__()
        self.encoder = nn.Sequential(
            nn.Conv2d(1,16,3,padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Conv2d(16,32,3,padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2,2),
            nn.Conv2d(32,64,3,padding=1),
            nn.ReLU(),
            nn.MaxPool2d(2,2)
        )
        self.decoder = nn.Sequential(
            nn.ConvTranspose2d(64,32,3,stride=2),
            nn.ReLU(),
            nn.ConvTranspose2d(32,16,2,stride=2),
            nn.ReLU(),
            nn.ConvTranspose2d(16,1,2,stride=2),
            nn.Sigmoid()
        )

    def forward(self, x):
        x = self.encoder(x)
        x = self.decoder(x)
        return x

autoencoder = CAE()
dae = DAE(autoencoder)

dae = dae.to(device)

optimizer = torch.optim.Adam(dae.parameters(), lr=0.001)

# Define the loss function and the training loop

criterion = (
    nn.MSELoss()
)

for epoch in range(2):
    for i, (images, _) in enumerate(train_x):
        # note that we do not flatten the images here
        images_recon = dae(images)
        # flatten the images for the loss calculation
        images = images.view(-1, 28*28).to(device)
        images_recon = images_recon.view(-1, 28*28).to(device)
        loss = criterion(images_recon, images)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
    print(f'Epoch {epoch+1}, Loss: {loss.item():.4f}')
# Out:
# Epoch 1, Loss: 0.0306
# Epoch 2, Loss: 0.0214

# %%
summary(dae, (1, 28, 28))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv2d-1           [-1, 16, 28, 28]             160
#               ReLU-2           [-1, 16, 28, 28]               0
#          MaxPool2d-3           [-1, 16, 14, 14]               0
#             Conv2d-4           [-1, 32, 14, 14]           4,640
#               ReLU-5           [-1, 32, 14, 14]               0
#          MaxPool2d-6             [-1, 32, 7, 7]               0
#             Conv2d-7             [-1, 64, 7, 7]          18,496
#               ReLU-8             [-1, 64, 7, 7]               0
#          MaxPool2d-9             [-1, 64, 3, 3]               0
#   ConvTranspose2d-10             [-1, 32, 7, 7]          18,464
#              ReLU-11             [-1, 32, 7, 7]               0
#   ConvTranspose2d-12           [-1, 16, 14, 14]           2,064
#              ReLU-13           [-1, 16, 14, 14]               0
#   ConvTranspose2d-14            [-1, 1, 28, 28]              65
#           Sigmoid-15            [-1, 1, 28, 28]               0
#               CAE-16            [-1, 1, 28, 28]               0
# ================================================================
# Total params: 43,889
# Trainable params: 43,889
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.00
# Forward/backward pass size (MB): 0.46
# Params size (MB): 0.17
# Estimated Total Size (MB): 0.64
# ----------------------------------------------------------------

# %%
# visualize original, noisy and reconstructed images
fig, axs = plt.subplots(3, 3, figsize=(6, 6))
for i, (images, _) in enumerate(train_x):
    images = images.to(device)
    noisy_imges = images + 0.5 * torch.randn_like(images)
    recon_images = dae.autoencoder(images)
    for ax, img in zip(axs[i, :], [images, noisy_imges, recon_images]):
        ax.imshow(img.view(28, 28).cpu().detach().numpy(), cmap='gray')
        ax.set_xticks([])
        ax.set_yticks([])
    if i == 2:
        break

# %% [markdown]
# The results are competitive with the fully connected autoencoder, but the convolutional autoencoder is much more parameter efficient (about 7 times less parameters).

# %% [markdown]
# ## Exercise 2
#
# In this exercise we will get acquainted with the KL divergence for normal distributions.
#
#
# **(a)** First, let $p(x)=\mathcal{N}(\mu_1,\sigma_1^2)$ and $q(x)=\mathcal{N}(\mu_2,\sigma_2^2)$
# and show that
#
# \begin{equation*}
# \text{KL}(q||p)
# = \mathbb{E}_{x\sim q}\left[\log\frac{q(x)}{p(x)}\right]
# =\log\frac{\sigma_1}{\sigma_2}+\frac{\sigma_2^2+(\mu_1-\mu_2)^2}{2\sigma_1^2} -\frac 1 2
# \end{equation*}
#
# **(b)** Now, consider a variational autoencoder that takes a vector as input $\textbf{x}$ and
# transforms it into a mean vector $\mu(\textbf{x})$ and a variance vector $\sigma(\textbf{x})^2$.
# From these, we derive the latent code $\textbf{z}\sim q(\textbf{z})=\mathcal{N}(\mu(\textbf{x}),\text{diag}(\sigma(\textbf{x})^2))$,
# i.e. a multivariate Gaussian in $d$ dimensions with a given mean vector and diagonal
# covariance matrix. The prior distribution for $\textbf{z}$ is another $d$-dimensional
# multivariate Gaussian $p=\mathcal{N}(\textbf{0},\textbf{1})$.
#
# Now show that:
#
# \begin{equation*}
# \text{KL}(q||p)= -\frac 1 2 \sum_{i=1}^d \left(1+\log\sigma_i(\textbf{x})^2-\sigma_i(\textbf{x})^2 - \mu_i(\textbf{x})^2 \right)
# \end{equation*}
#
# Hint: start by showing that $p$ and $q$ can be factorized into a product of independent
# Gaussian components, one for each dimension, then apply the formula for the KL
# divergence for the univariate case.
#
#
#
# ### Solution
#
# **(a)** We analyze each term separately:
#
# \begin{align}
# \mathbb{E}_{x\sim q}\left[\log q(x)\right]
# &= -\frac 1 2 \log(2\pi\sigma_2^2)+\mathbb{E}\left[-\frac{1}{2\sigma_2^2}\left(x-\mu_2\right)^2\right] \\
# &= -\frac 1 2 \log(2\pi\sigma_2^2) -\frac{1}{2\sigma_2^2}\left(\mathbb{E}[x^2]-2\mu_2\mathbb{E}[x]+\mu_2^2\right) \\
# &= -\frac 1 2 \log(2\pi\sigma_2^2) -\frac{1}{2\sigma_2^2}\left(\sigma_2^2+\mu_2^2-2\mu_2^2+\mu_2^2\right) \\
# &= -\frac 1 2(1+\log(2\pi\sigma_2^2))
# \end{align}
#
# and
#
# \begin{align}
# \mathbb{E}_{x\sim q}\left[\log p(x)\right]
# &= -\frac 1 2 \log(2\pi\sigma_1^2)+\mathbb{E}\left[-\frac{1}{2\sigma_1^2}\left(x-\mu_1\right)^2\right] \\
# &= -\frac 1 2 \log(2\pi\sigma_1^2) -\frac{1}{2\sigma_1^2}\left(\mathbb{E}[x^2]-2\mu_1\mathbb{E}[x]+\mu_1^2\right) \\
# &= -\frac 1 2 \log(2\pi\sigma_1^2) -\frac{1}{2\sigma_1^2}\left(\sigma_2^2+\mu_2^2-2\mu_1\mu_2+\mu_1^2\right) \\
# &= -\frac 1 2 \log(2\pi\sigma_1^2) -\frac{\sigma_2^2+(\mu_1-\mu_2)^2}{2\sigma_1^2}
# \end{align}
#
# Now taking the difference:
#
#
# \begin{align}
# \text{KL}(q||p)
# &=\mathbb{E}_{x\sim q}\left[\log q(x)\right] - \mathbb{E}_{x\sim q}\left[\log p(x)\right] \\
# &=-\frac 1 2(1+\log(2\pi\sigma_2^2))+\frac 1 2 \log(2\pi\sigma_1^2) +\frac{\sigma_2^2+(\mu_1-\mu_2)^2}{2\sigma_1^2} \\
# &=-\frac 1 2\left[1+\log(2\pi\sigma_2^2)-\log(2\pi\sigma_1^2)-\frac{\sigma_2^2+(\mu_1-\mu_2)^2}{\sigma_1^2}\right] \\
# &=-\frac 1 2\left[1+\log\frac{\sigma_2^2}{\sigma_1^2}-\frac{\sigma_2^2+(\mu_1-\mu_2)^2}{\sigma_1^2} \right] \\
# &= \log\frac{\sigma_1}{\sigma_2}+\frac{\sigma_2^2+(\mu_1-\mu_2)^2}{2\sigma_1^2} -\frac 1 2
# \end{align}
#
# **(b)** Moving to the second question, the expression for $p$ can be factorized as follows:
#
# \begin{align}
# q(\textbf{z})
# &=
#   (2\pi)^{-d/2}
#   \det(\text{diag}(\sigma(\textbf{x})^2))^{-1/2}
#   \exp\left(-\frac 1 2
#     (\textbf{z}-\mu(\textbf{x}))^T
#     \text{diag}(\sigma(\textbf{x})^2)^{-1}
#     (\textbf{z}-\mu(\textbf{x}))
#   \right) \\
# &=
#   (2\pi)^{-d/2}
#   \left(\prod_i \sigma_i(\textbf{x})^2\right)^{-1/2}
#   \exp\left(
#     -\frac 1 2 \sum_i \sigma_i(\textbf{x})^{-2}(z_i-\mu_i(\textbf{x}))^2
#   \right) \\
# &=
#   \prod_{i=1}^d
#   (2\pi\sigma_i(\textbf{x})^2)^{-1/2}
#   \exp\left(
#     -\frac{1}{2\sigma_i(\textbf{x})^2} (z_i-\mu_i(\textbf{x}))^2
#   \right) \\
# &=
#   \prod_{i=1}^d
#   \mathcal{N}(z_i|\mu_i(\textbf{x})^2, \sigma_i(\textbf{x})^2)
# \end{align}
#
# Where we made use of some convenient properties of diagonal matrices, namely that their
# determinant is the product of the elements on the diagonal, and that their inverse is
# again diagonal with the elements replaced by their reciprocal.
#
# Now since the mean of $p$ is zero and the covariance is the identity matrix, we have:
#
# \begin{equation}
# p(\textbf{z})=\prod_{i=1}^d\mathcal{N}(z_i|0, 1)
# \end{equation}
#
# We now plug these into the formula for the KL divergence to get:
#
# \begin{align}
# \text{KL}(q||p)
# &= \mathbb{E}_{x\sim q}\left[\log q(x)\right] - \mathbb{E}_{x\sim q}\left[\log p(x)\right] \\
# &= \mathbb{E}\left[\log\prod_{i=1}^d q(x)\right] - \mathbb{E}\left[\log\prod_{i=1}^d p_i(x)\right] \\
# &= \sum_{i=1}^d \mathbb{E}\left[\log q_i(x)\right] - \sum_i \mathbb{E}\left[\log p_i(x)\right] \\
# &= \sum_{i=1}^d \mathbb{E}\left[\log\frac{q_i(x)}{p_i(x)}\right] \\
# &= \sum_{i=1}^d \left(\log\frac{1}{\sigma_i(\textbf{x})}+\frac{\sigma_i(\textbf{x})^2+\mu(\textbf{x})^2}{2} -\frac 1 2\right) \\
# &= -\frac 1 2 \sum_{i=1}^d \left(1+\log\sigma_i(\textbf{x})^2-\sigma_i(\textbf{x})^2 - \mu_i(\textbf{x})^2 \right)
# \end{align}
#
#
# ## Exercise 3 (optional)
#
# In this exercise we are going to implement variational autoencoders (VAEs) on the MNIST
# dataset.

# %%
train_x = MNIST(root='.data', download=True, transform=ToTensor())

# %% [markdown]
# In a VAE, the encoder outputs mean and variance of a multivariate Gaussian distribution
# of the latent codes. Nothing prevents you from using a more complicated distribution in
# the same framework, but this is the usual choice. The expected log likelihood is then
# approximated by decoding a single sample from this distribution. Moreover, since we need
# the model to be differentiable end-to-end, sampling from the latent codes is
# re-formulated via the reparametrization trick.
#
# In the following we define a custom VAE module with a few utility functions that allow
# convenient managing of the VAE functionalities.

# %%
class VAE(nn.Module):

    # We pass the encoder and decoder over the constructor, which gives us more flexibility.
    def __init__(
            self,
            encoder: nn.Module,
            decoder: nn.Module,
            device: torch.device):
        super().__init__()
        self.encoder = encoder.to(device)
        self.decoder = decoder.to(device)
        self.device = device

        # We need a normal distribution for the reparametrization trick
        self.distribution = Normal(0, 1)

    # We define a utility function for sampling the eps with correct shape and device
    def sample_eps(self, sample_shape: Tuple) -> Tensor:
        sampled_eps: Tensor = self.distribution.sample(sample_shape)
        if str(self.device) != 'cpu':
            sampled_eps = sampled_eps.cuda()
        return sampled_eps

    # We output the reconstructed x as well as the latent mu and log variance.
    def forward(self, x: Tensor) -> Tuple[Tensor, Tensor, Tensor]:
        mu, log_var = self.encoder(x)
        std = torch.exp(0.5 * log_var)
        eps = self.sample_eps(std.shape)
        z = mu + eps * std
        x_hat = self.decoder(z)
        return x_hat, mu, log_var

    # We define an inference method for encoding input tensors.
    def encode(self, x: Tensor) -> Tensor:
        with torch.no_grad():
            mu, _ = self.encoder(x)
        return mu

    # We define an inference method for reconstructing z tensors.
    def reconstruct(self, z: Tensor) -> Tensor:
        with torch.no_grad():
            x_hat = self.decoder(z)
        return x_hat

# %% [markdown]
# Next, we create our encoder and decoder.
# The encoder will have two outputs, which is easily done via the `nn.Module` container.

# %%
class Encoder(nn.Module):
    def __init__(self, input_size: int, latent_size: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_features=input_size, out_features=256),
            nn.LeakyReLU(),
            nn.Linear(in_features=256, out_features=64),
            nn.LeakyReLU()
        )

        self.mu = nn.Sequential(
            nn.Linear(in_features=64, out_features=32),
            nn.LeakyReLU(),
            nn.Linear(in_features=32, out_features=latent_size),
            nn.LeakyReLU()
        )

        self.log_var = nn.Sequential(
            nn.Linear(in_features=64, out_features=32),
            nn.LeakyReLU(),
            nn.Linear(in_features=32, out_features=latent_size),
            nn.LeakyReLU()
        )

    def forward(self, x:Tensor) -> Tuple[Tensor, Tensor]:
        x = self.net(x)
        return self.mu(x), self.log_var(x)


class Decoder(nn.Module):
    def __init__(self, output_size: int, latent_size: int):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(in_features=latent_size, out_features=32),
            nn.LeakyReLU(),
            nn.Linear(in_features=32, out_features=64),
            nn.LeakyReLU(),
            nn.Linear(in_features=64, out_features=256),
            nn.LeakyReLU(),
            nn.Linear(in_features=256, out_features=output_size),
            nn.Sigmoid()
        )

    def forward(self, x:Tensor) -> Tuple[Tensor, Tensor]:
        return self.net(x)

# %% [markdown]
# A missing component is a Kullback-Leibler loss function, which we will define
# now for two Gaussians:

# %%
class KLDivergence:
    def __call__(self, mu: Tensor, log_var: Tensor) -> Tensor:
        return (
            -0.5 * torch.sum(1 + log_var - mu.pow(2) - log_var.exp()) / log_var.shape[0]
        )

# %% [markdown]
# Exactly like in the previous exercise, we again define our training iteration:

# %%
def train_autoencoder(
        vae: VAE,
        optimizer: Optimizer,
        mnist_dataset: MNIST,
        epochs: int,
        batch_size: int,
) -> List[float]:

    rec_loss = nn.MSELoss(reduction='sum')
    kl_loss = KLDivergence()

    train_losses = []

    num_train_batches = ceil(len(mnist_dataset) / batch_size)
    train_loader = DataLoader(mnist_dataset, batch_size, shuffle=True)

    for ep in range(1, epochs + 1):
        total_ep_loss = 0

        for batch_idx, (x, _) in enumerate(train_loader):
            x = x.to(vae.device).view(x.shape[0], -1)

            x_hat, mu, log_var = vae(x)
            batch_rec_loss = rec_loss(x, x_hat) / batch_size
            batch_kl_loss = kl_loss(mu, log_var) / x.shape[1]
            total_loss = batch_rec_loss + batch_kl_loss

            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

            if batch_idx % 10 == 0:
                print('TRAINING BATCH:\t({:5} / {:5})\tREC LOSS:\t{:2.3f}\tKL LOSS:\t{:2.3f}'
                      .format(batch_idx, num_train_batches, float(batch_rec_loss), float(batch_kl_loss)), end='\r')

            total_ep_loss += float(total_loss)

        train_losses.append(total_ep_loss / num_train_batches)
        print('EPOCH:\t{:5}\tTRAIN LOSS:\t{:.3f}'.format(ep, train_losses[-1], end='\r'))

    return train_losses

# %% [markdown]
# Finally, we can initialize all our classes and start the training!
# We will choose a latent size of 8.

# %%
latent_size = 8
epochs = 2
batch_size = 128


encoder = (
    Encoder(input_size=784, latent_size=8)
)

decoder = (
    Decoder(output_size=784, latent_size=8)
)

vae = (
    VAE(
        encoder=encoder,
        decoder=decoder,
        device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    )
)

optimizer = (
    Adam(vae.parameters())
)

train_autoencoder(vae, optimizer, train_x, epochs, batch_size)
# Out:
# TRAINING BATCH:	(   10 /   469)	REC LOSS:	146.262	KL LOSS:	0.000
# TRAINING BATCH:	(   30 /   469)	REC LOSS:	56.726	KL LOSS:	0.035
# TRAINING BATCH:	(   50 /   469)	REC LOSS:	57.833	KL LOSS:	0.003
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	50.718	KL LOSS:	0.006
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	51.655	KL LOSS:	0.018
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	50.634	KL LOSS:	0.045
# TRAINING BATCH:	(  130 /   469)	REC LOSS:	48.427	KL LOSS:	0.062
# TRAINING BATCH:	(  140 /   469)	REC LOSS:	48.229	KL LOSS:	0.049
# TRAINING BATCH:	(  150 /   469)	REC LOSS:	48.354	KL LOSS:	0.084
# TRAINING BATCH:	(  160 /   469)	REC LOSS:	50.352	KL LOSS:	0.075
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	47.828	KL LOSS:	0.081
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	43.379	KL LOSS:	0.133
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	44.870	KL LOSS:	0.136
# TRAINING BATCH:	(  230 /   469)	REC LOSS:	44.690	KL LOSS:	0.138
# TRAINING BATCH:	(  250 /   469)	REC LOSS:	44.948	KL LOSS:	0.140
# TRAINING BATCH:	(  270 /   469)	REC LOSS:	42.561	KL LOSS:	0.228
# TRAINING BATCH:	(  290 /   469)	REC LOSS:	40.621	KL LOSS:	0.211
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	40.049	KL LOSS:	0.250
# TRAINING BATCH:	(  330 /   469)	REC LOSS:	39.647	KL LOSS:	0.309
# TRAINING BATCH:	(  350 /   469)	REC LOSS:	37.019	KL LOSS:	0.316
# TRAINING BATCH:	(  370 /   469)	REC LOSS:	37.716	KL LOSS:	0.309
# TRAINING BATCH:	(  390 /   469)	REC LOSS:	33.323	KL LOSS:	0.318
# TRAINING BATCH:	(  410 /   469)	REC LOSS:	34.753	KL LOSS:	0.384
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	34.191	KL LOSS:	0.357
# TRAINING BATCH:	(  450 /   469)	REC LOSS:	33.915	KL LOSS:	0.333
# EPOCH:	    1	TRAIN LOSS:	47.789
# TRAINING BATCH:	(    0 /   469)	REC LOSS:	34.929	KL LOSS:	0.341
# TRAINING BATCH:	(   20 /   469)	REC LOSS:	32.106	KL LOSS:	0.372
# TRAINING BATCH:	(   40 /   469)	REC LOSS:	30.318	KL LOSS:	0.362
# TRAINING BATCH:	(   60 /   469)	REC LOSS:	31.265	KL LOSS:	0.361
# TRAINING BATCH:	(   80 /   469)	REC LOSS:	32.839	KL LOSS:	0.360
# TRAINING BATCH:	(  100 /   469)	REC LOSS:	30.403	KL LOSS:	0.356
# TRAINING BATCH:	(  120 /   469)	REC LOSS:	30.048	KL LOSS:	0.381
# TRAINING BATCH:	(  140 /   469)	REC LOSS:	31.248	KL LOSS:	0.383
# TRAINING BATCH:	(  160 /   469)	REC LOSS:	27.945	KL LOSS:	0.351
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	28.633	KL LOSS:	0.358
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	28.441	KL LOSS:	0.372
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	29.341	KL LOSS:	0.321
# TRAINING BATCH:	(  230 /   469)	REC LOSS:	27.608	KL LOSS:	0.353
# TRAINING BATCH:	(  250 /   469)	REC LOSS:	26.458	KL LOSS:	0.365
# TRAINING BATCH:	(  270 /   469)	REC LOSS:	28.011	KL LOSS:	0.368
# TRAINING BATCH:	(  290 /   469)	REC LOSS:	25.713	KL LOSS:	0.390
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	26.443	KL LOSS:	0.374
# TRAINING BATCH:	(  330 /   469)	REC LOSS:	26.242	KL LOSS:	0.376
# TRAINING BATCH:	(  350 /   469)	REC LOSS:	26.095	KL LOSS:	0.366
# TRAINING BATCH:	(  370 /   469)	REC LOSS:	25.062	KL LOSS:	0.364
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	23.829	KL LOSS:	0.390
# TRAINING BATCH:	(  390 /   469)	REC LOSS:	25.331	KL LOSS:	0.392
# TRAINING BATCH:	(  410 /   469)	REC LOSS:	25.564	KL LOSS:	0.382
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	24.058	KL LOSS:	0.381
# TRAINING BATCH:	(  450 /   469)	REC LOSS:	24.647	KL LOSS:	0.384
# EPOCH:	    2	TRAIN LOSS:	28.166
# [47.78946602420766, 28.166220862219838]

# %% [markdown]
# Let us check the reconstruction of a digit:

# %%
def plot_reconstruction_grid(vae: nn.Module, mnist_dataset: MNIST) -> None:
    x_samples = mnist_dataset.data[:100] / 255
    z = vae.encode(x_samples.to(vae.device).view(100, -1))
    x_hat = vae.reconstruct(z).detach().cpu().view(100, 28, 28)

    cur_col = 0
    image_list = []
    for _ in range(4):
        image_list.extend(x_samples[cur_col:cur_col + 25])
        image_list.extend(x_hat[cur_col:cur_col + 25])
        cur_col += 25

    image_batch = torch.stack(image_list).unsqueeze(1)
    image_grid = make_grid(image_batch, nrow=25)
    plt.imshow(image_grid.permute(1, 2, 0))
    plt.axis('off')
    plt.show()

# %%
plot_reconstruction_grid(vae, train_x)

# %% [markdown]
# It is already quite good for only two training epochs!
# Now try to remove the division of the KL by 784, train again and visualize the result.
#
# You should see a gray blob that looks a bit like the average of many digits.
# This phenomenon is named _mode collapse_, i.e. the distribution of the generator
# collapsed to a single mode that covers the entire dataset, instead of (at least)
# one mode for every digit. In VAEs, this is typically caused by a KL term that is
# very strong at the beginning of training, and dominates the reconstruction loss.
# The optimizer will focus most of its efforts to reduce this term, ending up in a poor local minimum.
#
# A popular method to deal with this issue is _KL annealing_.
# It consists in training the network without the KL regularizer for some time, then slowly
# increasing the weight of the KL. This procedure allows the network to first learn how to
# perform good reconstructions, then to adjust the latent code to conform to a Normal
# distribution without erasing progress on the reconstruction.
#
# To implement this behaviour, we define a small object that is able to return the
# desired KL weight in the respective epoch.

# %%
class KLWeightManager:
    """
    Manager to get the desired KL weight.

    Warm up rounds specify the starting epochs until which the KL weight will be zero.
    The annealing rounds describe the duration of the annealing process.
    E.g., warm up is 5 and and there are 10 annealing rounds, then the first 5 epochs
    will have a KL weight of 0 and from epoch 5 to 15 the weight will be annealed to 1.
    """
    def __init__(self, warm_up_rounds: int, annealing_rounds: int):
        self.warm_up = warm_up_rounds
        self.annealing_rounds = annealing_rounds


    def __call__(self, cur_epoch: int) -> float:
        if cur_epoch < self.warm_up:
            return 0.0
        elif cur_epoch >= self.warm_up + self.annealing_rounds:
            return 1.0
        else:
            progress = cur_epoch - self.warm_up
            return progress / self.annealing_rounds

# %% [markdown]
# Let's remove the scaling term in the training loop and integrate the `KLWeightManager`:

# %%
def train_autoencoder(
        vae: VAE,
        optimizer: Optimizer,
        mnist_dataset: MNIST,
        epochs: int,
        batch_size: int,
) -> List[float]:

    rec_loss = nn.MSELoss(reduction='sum')
    kl_loss = KLDivergence()
    kl_weighting = KLWeightManager(warm_up_rounds=0, annealing_rounds=5)

    train_losses = []

    num_train_batches = ceil(len(mnist_dataset) / batch_size)
    train_loader = DataLoader(mnist_dataset, batch_size, shuffle=True)

    for ep in range(1, epochs + 1):
        total_ep_loss = 0

        for batch_idx, (x, _) in enumerate(train_loader):
            x = x.to(vae.device).view(x.shape[0], -1)

            x_hat, mu, log_var = vae(x)
            batch_rec_loss = rec_loss(x, x_hat) / batch_size
            batch_kl_loss = kl_loss(mu, log_var)
            total_loss = batch_rec_loss + kl_weighting(ep) * batch_kl_loss

            optimizer.zero_grad()
            total_loss.backward()
            optimizer.step()

            if batch_idx % 10 == 0:
                print('TRAINING BATCH:\t({:5} / {:5})\tREC LOSS:\t{:2.3f}\tKL LOSS:\t{:2.3f}'
                      .format(batch_idx, num_train_batches, float(batch_rec_loss), float(batch_kl_loss)), end='\r')

            total_ep_loss += float(total_loss)

        train_losses.append(total_ep_loss / num_train_batches)
        print('EPOCH:\t{:5}\tTRAIN LOSS:\t{:.3f}\tKL WEIGHT:\t{:.2f}'
              .format(ep, train_losses[-1], kl_weighting(ep), end='\r'))

    return train_losses

# %%
latent_size = 8
epochs = 15
batch_size = 128


encoder = (
    Encoder(input_size=784, latent_size=8)
)

decoder = (
    Decoder(output_size=784, latent_size=8)
)

vae = (
    VAE(
        encoder=encoder,
        decoder=decoder,
        device=torch.device('cuda' if torch.cuda.is_available() else 'cpu')
    )
)

optimizer = (
    Adam(vae.parameters())
)

losses = train_autoencoder(vae, optimizer, train_x, epochs, batch_size)
# Out:
# TRAINING BATCH:	(    0 /   469)	REC LOSS:	181.738	KL LOSS:	0.023
# TRAINING BATCH:	(   10 /   469)	REC LOSS:	148.071	KL LOSS:	0.267
# TRAINING BATCH:	(   20 /   469)	REC LOSS:	72.249	KL LOSS:	42.044
# TRAINING BATCH:	(   30 /   469)	REC LOSS:	54.717	KL LOSS:	2.396
# TRAINING BATCH:	(   40 /   469)	REC LOSS:	56.079	KL LOSS:	0.412
# TRAINING BATCH:	(   50 /   469)	REC LOSS:	52.676	KL LOSS:	0.092
# TRAINING BATCH:	(   60 /   469)	REC LOSS:	52.282	KL LOSS:	0.014
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	51.803	KL LOSS:	0.129
# TRAINING BATCH:	(   80 /   469)	REC LOSS:	51.195	KL LOSS:	0.165
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	51.739	KL LOSS:	0.422
# TRAINING BATCH:	(  100 /   469)	REC LOSS:	52.831	KL LOSS:	0.748
# TRAINING BATCH:	(  120 /   469)	REC LOSS:	52.760	KL LOSS:	2.169
# TRAINING BATCH:	(  140 /   469)	REC LOSS:	49.956	KL LOSS:	3.158
# TRAINING BATCH:	(  160 /   469)	REC LOSS:	51.889	KL LOSS:	2.562
# TRAINING BATCH:	(  180 /   469)	REC LOSS:	51.179	KL LOSS:	3.650
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	48.049	KL LOSS:	4.344
# TRAINING BATCH:	(  220 /   469)	REC LOSS:	48.313	KL LOSS:	3.833
# TRAINING BATCH:	(  240 /   469)	REC LOSS:	44.472	KL LOSS:	4.797
# TRAINING BATCH:	(  260 /   469)	REC LOSS:	47.273	KL LOSS:	4.195
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	48.004	KL LOSS:	4.567
# TRAINING BATCH:	(  300 /   469)	REC LOSS:	46.894	KL LOSS:	4.196
# TRAINING BATCH:	(  320 /   469)	REC LOSS:	45.146	KL LOSS:	5.315
# TRAINING BATCH:	(  340 /   469)	REC LOSS:	44.802	KL LOSS:	6.331
# TRAINING BATCH:	(  360 /   469)	REC LOSS:	43.580	KL LOSS:	6.376
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	43.581	KL LOSS:	7.086
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	42.574	KL LOSS:	7.171
# TRAINING BATCH:	(  420 /   469)	REC LOSS:	41.195	KL LOSS:	8.739
# TRAINING BATCH:	(  440 /   469)	REC LOSS:	44.137	KL LOSS:	7.377
# TRAINING BATCH:	(  460 /   469)	REC LOSS:	41.906	KL LOSS:	7.554
# EPOCH:	    1	TRAIN LOSS:	52.732	KL WEIGHT:	0.20
# TRAINING BATCH:	(   10 /   469)	REC LOSS:	42.014	KL LOSS:	7.000
# TRAINING BATCH:	(   30 /   469)	REC LOSS:	41.656	KL LOSS:	6.807
# TRAINING BATCH:	(   50 /   469)	REC LOSS:	41.328	KL LOSS:	6.386
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	39.131	KL LOSS:	7.607
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	38.627	KL LOSS:	7.084
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	37.109	KL LOSS:	8.798
# TRAINING BATCH:	(  130 /   469)	REC LOSS:	40.007	KL LOSS:	8.853
# TRAINING BATCH:	(  150 /   469)	REC LOSS:	37.802	KL LOSS:	7.982
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	38.417	KL LOSS:	8.822
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	34.793	KL LOSS:	9.128
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	34.107	KL LOSS:	8.671
# TRAINING BATCH:	(  230 /   469)	REC LOSS:	36.327	KL LOSS:	9.746
# TRAINING BATCH:	(  250 /   469)	REC LOSS:	35.206	KL LOSS:	9.668
# TRAINING BATCH:	(  270 /   469)	REC LOSS:	35.634	KL LOSS:	9.340
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	34.493	KL LOSS:	9.984
# TRAINING BATCH:	(  300 /   469)	REC LOSS:	33.863	KL LOSS:	9.087
# TRAINING BATCH:	(  320 /   469)	REC LOSS:	31.594	KL LOSS:	10.277
# TRAINING BATCH:	(  340 /   469)	REC LOSS:	33.383	KL LOSS:	9.553
# TRAINING BATCH:	(  360 /   469)	REC LOSS:	34.206	KL LOSS:	10.361
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	34.152	KL LOSS:	9.564
# TRAINING BATCH:	(  390 /   469)	REC LOSS:	32.470	KL LOSS:	9.950
# TRAINING BATCH:	(  410 /   469)	REC LOSS:	33.134	KL LOSS:	9.431
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	33.769	KL LOSS:	10.386
# TRAINING BATCH:	(  450 /   469)	REC LOSS:	33.231	KL LOSS:	10.353
# EPOCH:	    2	TRAIN LOSS:	39.785	KL WEIGHT:	0.40
# TRAINING BATCH:	(    0 /   469)	REC LOSS:	32.454	KL LOSS:	9.900
# TRAINING BATCH:	(   10 /   469)	REC LOSS:	31.405	KL LOSS:	8.628
# TRAINING BATCH:	(   20 /   469)	REC LOSS:	32.340	KL LOSS:	8.433
# TRAINING BATCH:	(   40 /   469)	REC LOSS:	34.865	KL LOSS:	8.993
# TRAINING BATCH:	(   50 /   469)	REC LOSS:	33.272	KL LOSS:	9.101
# TRAINING BATCH:	(   60 /   469)	REC LOSS:	34.694	KL LOSS:	8.453
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	33.347	KL LOSS:	8.891
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	34.834	KL LOSS:	9.245
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	29.931	KL LOSS:	8.991
# TRAINING BATCH:	(  130 /   469)	REC LOSS:	32.410	KL LOSS:	8.183
# TRAINING BATCH:	(  150 /   469)	REC LOSS:	34.502	KL LOSS:	9.457
# TRAINING BATCH:	(  160 /   469)	REC LOSS:	32.275	KL LOSS:	8.948
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	32.252	KL LOSS:	8.735
# TRAINING BATCH:	(  180 /   469)	REC LOSS:	33.435	KL LOSS:	8.485
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	32.578	KL LOSS:	9.125
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	32.376	KL LOSS:	9.148
# TRAINING BATCH:	(  220 /   469)	REC LOSS:	32.219	KL LOSS:	9.286
# TRAINING BATCH:	(  230 /   469)	REC LOSS:	33.074	KL LOSS:	9.555
# TRAINING BATCH:	(  250 /   469)	REC LOSS:	30.530	KL LOSS:	9.361
# TRAINING BATCH:	(  260 /   469)	REC LOSS:	32.281	KL LOSS:	9.306
# TRAINING BATCH:	(  270 /   469)	REC LOSS:	30.589	KL LOSS:	9.619
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	32.271	KL LOSS:	9.215
# TRAINING BATCH:	(  290 /   469)	REC LOSS:	32.028	KL LOSS:	8.957
# TRAINING BATCH:	(  300 /   469)	REC LOSS:	30.045	KL LOSS:	9.368
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	30.175	KL LOSS:	9.682
# TRAINING BATCH:	(  320 /   469)	REC LOSS:	29.939	KL LOSS:	9.711
# TRAINING BATCH:	(  340 /   469)	REC LOSS:	30.618	KL LOSS:	9.780
# TRAINING BATCH:	(  360 /   469)	REC LOSS:	27.845	KL LOSS:	9.886
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	30.078	KL LOSS:	9.885
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	30.549	KL LOSS:	9.506
# TRAINING BATCH:	(  420 /   469)	REC LOSS:	29.685	KL LOSS:	10.075
# TRAINING BATCH:	(  440 /   469)	REC LOSS:	28.876	KL LOSS:	10.008
# TRAINING BATCH:	(  460 /   469)	REC LOSS:	29.366	KL LOSS:	10.180
# EPOCH:	    3	TRAIN LOSS:	37.059	KL WEIGHT:	0.60
# TRAINING BATCH:	(   10 /   469)	REC LOSS:	29.880	KL LOSS:	9.007
# TRAINING BATCH:	(   30 /   469)	REC LOSS:	28.451	KL LOSS:	9.703
# TRAINING BATCH:	(   50 /   469)	REC LOSS:	29.214	KL LOSS:	9.579
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	28.603	KL LOSS:	9.348
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	30.705	KL LOSS:	8.897
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	30.841	KL LOSS:	9.090
# TRAINING BATCH:	(  130 /   469)	REC LOSS:	31.121	KL LOSS:	9.067
# TRAINING BATCH:	(  150 /   469)	REC LOSS:	30.188	KL LOSS:	9.133
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	29.126	KL LOSS:	9.413
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	30.160	KL LOSS:	9.015
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	28.248	KL LOSS:	9.369
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	28.402	KL LOSS:	8.698
# TRAINING BATCH:	(  230 /   469)	REC LOSS:	27.563	KL LOSS:	8.900
# TRAINING BATCH:	(  250 /   469)	REC LOSS:	29.230	KL LOSS:	9.107
# TRAINING BATCH:	(  260 /   469)	REC LOSS:	26.635	KL LOSS:	8.943
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	28.321	KL LOSS:	9.424
# TRAINING BATCH:	(  300 /   469)	REC LOSS:	27.154	KL LOSS:	9.723
# TRAINING BATCH:	(  320 /   469)	REC LOSS:	27.934	KL LOSS:	9.200
# TRAINING BATCH:	(  330 /   469)	REC LOSS:	27.542	KL LOSS:	9.844
# TRAINING BATCH:	(  340 /   469)	REC LOSS:	26.700	KL LOSS:	9.686
# TRAINING BATCH:	(  350 /   469)	REC LOSS:	26.552	KL LOSS:	8.918
# TRAINING BATCH:	(  370 /   469)	REC LOSS:	28.665	KL LOSS:	9.566
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	28.486	KL LOSS:	9.779
# TRAINING BATCH:	(  390 /   469)	REC LOSS:	28.516	KL LOSS:	9.063
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	28.549	KL LOSS:	9.503
# TRAINING BATCH:	(  410 /   469)	REC LOSS:	30.128	KL LOSS:	9.554
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	28.136	KL LOSS:	9.305
# TRAINING BATCH:	(  440 /   469)	REC LOSS:	29.605	KL LOSS:	9.547
# TRAINING BATCH:	(  450 /   469)	REC LOSS:	28.308	KL LOSS:	8.999
# EPOCH:	    4	TRAIN LOSS:	36.553	KL WEIGHT:	0.80
# TRAINING BATCH:	(    0 /   469)	REC LOSS:	27.624	KL LOSS:	9.196
# TRAINING BATCH:	(   20 /   469)	REC LOSS:	28.837	KL LOSS:	8.862
# TRAINING BATCH:	(   40 /   469)	REC LOSS:	29.592	KL LOSS:	9.307
# TRAINING BATCH:	(   60 /   469)	REC LOSS:	26.306	KL LOSS:	9.105
# TRAINING BATCH:	(   80 /   469)	REC LOSS:	27.965	KL LOSS:	8.816
# TRAINING BATCH:	(  100 /   469)	REC LOSS:	28.104	KL LOSS:	8.628
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	27.593	KL LOSS:	8.801
# TRAINING BATCH:	(  120 /   469)	REC LOSS:	28.220	KL LOSS:	8.721
# TRAINING BATCH:	(  140 /   469)	REC LOSS:	27.932	KL LOSS:	8.974
# TRAINING BATCH:	(  160 /   469)	REC LOSS:	28.937	KL LOSS:	8.943
# TRAINING BATCH:	(  180 /   469)	REC LOSS:	27.753	KL LOSS:	8.607
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	28.822	KL LOSS:	8.960
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	28.304	KL LOSS:	8.632
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	28.544	KL LOSS:	8.811
# TRAINING BATCH:	(  220 /   469)	REC LOSS:	28.405	KL LOSS:	8.760
# TRAINING BATCH:	(  240 /   469)	REC LOSS:	29.383	KL LOSS:	8.748
# TRAINING BATCH:	(  250 /   469)	REC LOSS:	29.025	KL LOSS:	9.265
# TRAINING BATCH:	(  270 /   469)	REC LOSS:	27.813	KL LOSS:	8.745
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	28.893	KL LOSS:	8.856
# TRAINING BATCH:	(  290 /   469)	REC LOSS:	28.728	KL LOSS:	8.921
# TRAINING BATCH:	(  300 /   469)	REC LOSS:	28.082	KL LOSS:	8.965
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	26.541	KL LOSS:	8.891
# TRAINING BATCH:	(  320 /   469)	REC LOSS:	30.059	KL LOSS:	8.868
# TRAINING BATCH:	(  340 /   469)	REC LOSS:	28.392	KL LOSS:	8.761
# TRAINING BATCH:	(  350 /   469)	REC LOSS:	27.753	KL LOSS:	9.266
# TRAINING BATCH:	(  370 /   469)	REC LOSS:	28.432	KL LOSS:	9.126
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	26.981	KL LOSS:	8.941
# TRAINING BATCH:	(  390 /   469)	REC LOSS:	27.325	KL LOSS:	8.824
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	26.041	KL LOSS:	8.997
# TRAINING BATCH:	(  410 /   469)	REC LOSS:	29.280	KL LOSS:	8.871
# TRAINING BATCH:	(  420 /   469)	REC LOSS:	29.403	KL LOSS:	9.051
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	26.319	KL LOSS:	8.815
# TRAINING BATCH:	(  440 /   469)	REC LOSS:	29.254	KL LOSS:	8.870
# TRAINING BATCH:	(  450 /   469)	REC LOSS:	28.067	KL LOSS:	9.167
# EPOCH:	    5	TRAIN LOSS:	37.338	KL WEIGHT:	1.00
# TRAINING BATCH:	(    0 /   469)	REC LOSS:	26.826	KL LOSS:	8.438
# TRAINING BATCH:	(   20 /   469)	REC LOSS:	27.573	KL LOSS:	8.627
# TRAINING BATCH:	(   40 /   469)	REC LOSS:	28.414	KL LOSS:	8.796
# TRAINING BATCH:	(   60 /   469)	REC LOSS:	28.398	KL LOSS:	9.064
# TRAINING BATCH:	(   80 /   469)	REC LOSS:	28.939	KL LOSS:	8.610
# TRAINING BATCH:	(  100 /   469)	REC LOSS:	26.916	KL LOSS:	9.098
# TRAINING BATCH:	(  120 /   469)	REC LOSS:	29.192	KL LOSS:	8.526
# TRAINING BATCH:	(  140 /   469)	REC LOSS:	28.457	KL LOSS:	8.858
# TRAINING BATCH:	(  160 /   469)	REC LOSS:	26.812	KL LOSS:	9.058
# TRAINING BATCH:	(  180 /   469)	REC LOSS:	26.906	KL LOSS:	9.096
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	28.562	KL LOSS:	8.913
# TRAINING BATCH:	(  220 /   469)	REC LOSS:	27.439	KL LOSS:	8.723
# TRAINING BATCH:	(  240 /   469)	REC LOSS:	27.768	KL LOSS:	9.194
# TRAINING BATCH:	(  260 /   469)	REC LOSS:	26.387	KL LOSS:	9.313
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	27.208	KL LOSS:	8.600
# TRAINING BATCH:	(  300 /   469)	REC LOSS:	27.902	KL LOSS:	9.372
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	26.502	KL LOSS:	9.253
# TRAINING BATCH:	(  330 /   469)	REC LOSS:	26.574	KL LOSS:	9.140
# TRAINING BATCH:	(  350 /   469)	REC LOSS:	28.662	KL LOSS:	8.805
# TRAINING BATCH:	(  370 /   469)	REC LOSS:	25.642	KL LOSS:	9.482
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	28.325	KL LOSS:	8.893
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	27.015	KL LOSS:	9.231
# TRAINING BATCH:	(  410 /   469)	REC LOSS:	27.204	KL LOSS:	9.535
# TRAINING BATCH:	(  420 /   469)	REC LOSS:	27.319	KL LOSS:	9.037
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	28.993	KL LOSS:	9.028
# TRAINING BATCH:	(  440 /   469)	REC LOSS:	27.401	KL LOSS:	8.978
# TRAINING BATCH:	(  450 /   469)	REC LOSS:	27.471	KL LOSS:	8.837
# EPOCH:	    6	TRAIN LOSS:	36.740	KL WEIGHT:	1.00
# TRAINING BATCH:	(    0 /   469)	REC LOSS:	27.246	KL LOSS:	9.353
# TRAINING BATCH:	(   20 /   469)	REC LOSS:	29.684	KL LOSS:	9.247
# TRAINING BATCH:	(   40 /   469)	REC LOSS:	27.426	KL LOSS:	9.106
# TRAINING BATCH:	(   60 /   469)	REC LOSS:	27.374	KL LOSS:	8.806
# TRAINING BATCH:	(   80 /   469)	REC LOSS:	28.843	KL LOSS:	9.022
# TRAINING BATCH:	(  100 /   469)	REC LOSS:	27.456	KL LOSS:	8.915
# TRAINING BATCH:	(  120 /   469)	REC LOSS:	28.217	KL LOSS:	9.178
# TRAINING BATCH:	(  130 /   469)	REC LOSS:	26.633	KL LOSS:	8.886
# TRAINING BATCH:	(  150 /   469)	REC LOSS:	28.439	KL LOSS:	9.213
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	25.475	KL LOSS:	9.088
# TRAINING BATCH:	(  180 /   469)	REC LOSS:	27.217	KL LOSS:	9.242
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	26.448	KL LOSS:	9.367
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	27.972	KL LOSS:	9.137
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	26.347	KL LOSS:	9.216
# TRAINING BATCH:	(  220 /   469)	REC LOSS:	26.432	KL LOSS:	9.311
# TRAINING BATCH:	(  240 /   469)	REC LOSS:	25.317	KL LOSS:	9.187
# TRAINING BATCH:	(  250 /   469)	REC LOSS:	28.309	KL LOSS:	9.110
# TRAINING BATCH:	(  260 /   469)	REC LOSS:	26.550	KL LOSS:	8.923
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	27.806	KL LOSS:	8.976
# TRAINING BATCH:	(  290 /   469)	REC LOSS:	28.105	KL LOSS:	9.890
# TRAINING BATCH:	(  300 /   469)	REC LOSS:	28.592	KL LOSS:	8.911
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	28.501	KL LOSS:	9.313
# TRAINING BATCH:	(  320 /   469)	REC LOSS:	27.483	KL LOSS:	9.168
# TRAINING BATCH:	(  330 /   469)	REC LOSS:	25.884	KL LOSS:	8.895
# TRAINING BATCH:	(  340 /   469)	REC LOSS:	25.745	KL LOSS:	9.321
# TRAINING BATCH:	(  350 /   469)	REC LOSS:	27.087	KL LOSS:	8.777
# TRAINING BATCH:	(  360 /   469)	REC LOSS:	28.227	KL LOSS:	9.321
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	26.729	KL LOSS:	9.168
# TRAINING BATCH:	(  390 /   469)	REC LOSS:	28.063	KL LOSS:	9.099
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	27.046	KL LOSS:	9.190
# TRAINING BATCH:	(  410 /   469)	REC LOSS:	26.464	KL LOSS:	9.046
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	27.182	KL LOSS:	9.380
# TRAINING BATCH:	(  450 /   469)	REC LOSS:	26.446	KL LOSS:	8.789
# EPOCH:	    7	TRAIN LOSS:	36.237	KL WEIGHT:	1.00
# TRAINING BATCH:	(    0 /   469)	REC LOSS:	27.086	KL LOSS:	9.616
# TRAINING BATCH:	(   10 /   469)	REC LOSS:	26.453	KL LOSS:	9.462
# TRAINING BATCH:	(   20 /   469)	REC LOSS:	27.111	KL LOSS:	9.206
# TRAINING BATCH:	(   30 /   469)	REC LOSS:	26.542	KL LOSS:	9.240
# TRAINING BATCH:	(   40 /   469)	REC LOSS:	25.919	KL LOSS:	9.308
# TRAINING BATCH:	(   50 /   469)	REC LOSS:	25.536	KL LOSS:	9.384
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	27.599	KL LOSS:	9.013
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	27.765	KL LOSS:	9.140
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	25.175	KL LOSS:	9.194
# TRAINING BATCH:	(  120 /   469)	REC LOSS:	26.351	KL LOSS:	8.959
# TRAINING BATCH:	(  130 /   469)	REC LOSS:	26.849	KL LOSS:	9.462
# TRAINING BATCH:	(  140 /   469)	REC LOSS:	26.061	KL LOSS:	8.728
# TRAINING BATCH:	(  150 /   469)	REC LOSS:	27.519	KL LOSS:	8.972
# TRAINING BATCH:	(  160 /   469)	REC LOSS:	26.768	KL LOSS:	9.374
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	26.521	KL LOSS:	9.497
# TRAINING BATCH:	(  180 /   469)	REC LOSS:	26.728	KL LOSS:	9.236
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	25.965	KL LOSS:	9.423
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	28.175	KL LOSS:	9.416
# TRAINING BATCH:	(  220 /   469)	REC LOSS:	26.189	KL LOSS:	9.087
# TRAINING BATCH:	(  230 /   469)	REC LOSS:	27.441	KL LOSS:	9.229
# TRAINING BATCH:	(  240 /   469)	REC LOSS:	24.919	KL LOSS:	9.264
# TRAINING BATCH:	(  260 /   469)	REC LOSS:	26.672	KL LOSS:	9.327
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	26.946	KL LOSS:	9.258
# TRAINING BATCH:	(  300 /   469)	REC LOSS:	27.303	KL LOSS:	9.011
# TRAINING BATCH:	(  320 /   469)	REC LOSS:	26.325	KL LOSS:	9.256
# TRAINING BATCH:	(  340 /   469)	REC LOSS:	25.825	KL LOSS:	9.201
# TRAINING BATCH:	(  360 /   469)	REC LOSS:	26.737	KL LOSS:	9.151
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	26.163	KL LOSS:	9.399
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	25.799	KL LOSS:	9.077
# TRAINING BATCH:	(  420 /   469)	REC LOSS:	25.647	KL LOSS:	9.494
# TRAINING BATCH:	(  440 /   469)	REC LOSS:	24.206	KL LOSS:	9.468
# TRAINING BATCH:	(  460 /   469)	REC LOSS:	26.715	KL LOSS:	9.344
# EPOCH:	    8	TRAIN LOSS:	35.882	KL WEIGHT:	1.00
# TRAINING BATCH:	(   10 /   469)	REC LOSS:	25.695	KL LOSS:	9.108
# TRAINING BATCH:	(   30 /   469)	REC LOSS:	24.631	KL LOSS:	9.452
# TRAINING BATCH:	(   50 /   469)	REC LOSS:	27.434	KL LOSS:	9.584
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	27.061	KL LOSS:	9.307
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	24.113	KL LOSS:	8.937
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	26.529	KL LOSS:	9.590
# TRAINING BATCH:	(  130 /   469)	REC LOSS:	23.892	KL LOSS:	9.024
# TRAINING BATCH:	(  150 /   469)	REC LOSS:	25.971	KL LOSS:	9.284
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	26.698	KL LOSS:	9.756
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	26.731	KL LOSS:	9.390
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	27.440	KL LOSS:	8.843
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	25.036	KL LOSS:	9.007
# TRAINING BATCH:	(  230 /   469)	REC LOSS:	25.914	KL LOSS:	9.353
# TRAINING BATCH:	(  250 /   469)	REC LOSS:	26.158	KL LOSS:	9.793
# TRAINING BATCH:	(  270 /   469)	REC LOSS:	26.200	KL LOSS:	9.523
# TRAINING BATCH:	(  290 /   469)	REC LOSS:	26.701	KL LOSS:	9.617
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	26.207	KL LOSS:	9.117
# TRAINING BATCH:	(  330 /   469)	REC LOSS:	24.670	KL LOSS:	9.888
# TRAINING BATCH:	(  350 /   469)	REC LOSS:	23.406	KL LOSS:	9.396
# TRAINING BATCH:	(  370 /   469)	REC LOSS:	26.872	KL LOSS:	9.264
# TRAINING BATCH:	(  390 /   469)	REC LOSS:	26.386	KL LOSS:	9.449
# TRAINING BATCH:	(  410 /   469)	REC LOSS:	25.968	KL LOSS:	9.458
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	26.194	KL LOSS:	9.498
# TRAINING BATCH:	(  450 /   469)	REC LOSS:	27.462	KL LOSS:	9.179
# EPOCH:	    9	TRAIN LOSS:	35.554	KL WEIGHT:	1.00
# TRAINING BATCH:	(   10 /   469)	REC LOSS:	29.021	KL LOSS:	9.508
# TRAINING BATCH:	(   30 /   469)	REC LOSS:	25.589	KL LOSS:	9.694
# TRAINING BATCH:	(   50 /   469)	REC LOSS:	26.554	KL LOSS:	9.447
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	25.779	KL LOSS:	9.972
# TRAINING BATCH:	(   80 /   469)	REC LOSS:	24.472	KL LOSS:	8.976
# TRAINING BATCH:	(  100 /   469)	REC LOSS:	25.748	KL LOSS:	9.043
# TRAINING BATCH:	(  120 /   469)	REC LOSS:	25.372	KL LOSS:	9.472
# TRAINING BATCH:	(  140 /   469)	REC LOSS:	25.941	KL LOSS:	9.139
# TRAINING BATCH:	(  160 /   469)	REC LOSS:	25.957	KL LOSS:	9.559
# TRAINING BATCH:	(  180 /   469)	REC LOSS:	25.313	KL LOSS:	9.788
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	25.970	KL LOSS:	9.915
# TRAINING BATCH:	(  220 /   469)	REC LOSS:	25.910	KL LOSS:	9.944
# TRAINING BATCH:	(  240 /   469)	REC LOSS:	26.173	KL LOSS:	9.329
# TRAINING BATCH:	(  260 /   469)	REC LOSS:	25.086	KL LOSS:	9.625
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	27.322	KL LOSS:	9.493
# TRAINING BATCH:	(  300 /   469)	REC LOSS:	24.989	KL LOSS:	9.873
# TRAINING BATCH:	(  320 /   469)	REC LOSS:	24.948	KL LOSS:	9.727
# TRAINING BATCH:	(  340 /   469)	REC LOSS:	26.844	KL LOSS:	9.497
# TRAINING BATCH:	(  360 /   469)	REC LOSS:	25.090	KL LOSS:	9.625
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	24.943	KL LOSS:	9.666
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	26.232	KL LOSS:	9.253
# TRAINING BATCH:	(  420 /   469)	REC LOSS:	27.443	KL LOSS:	9.700
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	26.396	KL LOSS:	8.760
# TRAINING BATCH:	(  440 /   469)	REC LOSS:	25.230	KL LOSS:	9.463
# TRAINING BATCH:	(  450 /   469)	REC LOSS:	25.223	KL LOSS:	9.494
# EPOCH:	   10	TRAIN LOSS:	35.293	KL WEIGHT:	1.00
# TRAINING BATCH:	(    0 /   469)	REC LOSS:	25.341	KL LOSS:	9.612
# TRAINING BATCH:	(   20 /   469)	REC LOSS:	26.702	KL LOSS:	9.411
# TRAINING BATCH:	(   30 /   469)	REC LOSS:	25.644	KL LOSS:	9.243
# TRAINING BATCH:	(   50 /   469)	REC LOSS:	26.884	KL LOSS:	9.873
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	25.830	KL LOSS:	9.704
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	23.396	KL LOSS:	9.620
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	25.085	KL LOSS:	9.395
# TRAINING BATCH:	(  130 /   469)	REC LOSS:	25.674	KL LOSS:	9.429
# TRAINING BATCH:	(  150 /   469)	REC LOSS:	24.625	KL LOSS:	9.491
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	25.488	KL LOSS:	9.842
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	25.340	KL LOSS:	9.383
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	25.354	KL LOSS:	9.765
# TRAINING BATCH:	(  230 /   469)	REC LOSS:	25.131	KL LOSS:	9.579
# TRAINING BATCH:	(  250 /   469)	REC LOSS:	25.717	KL LOSS:	9.561
# TRAINING BATCH:	(  270 /   469)	REC LOSS:	24.672	KL LOSS:	9.543
# TRAINING BATCH:	(  290 /   469)	REC LOSS:	25.623	KL LOSS:	9.534
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	25.002	KL LOSS:	9.333
# TRAINING BATCH:	(  330 /   469)	REC LOSS:	24.970	KL LOSS:	9.351
# TRAINING BATCH:	(  350 /   469)	REC LOSS:	26.427	KL LOSS:	9.892
# TRAINING BATCH:	(  370 /   469)	REC LOSS:	25.020	KL LOSS:	9.483
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	25.624	KL LOSS:	9.638
# TRAINING BATCH:	(  390 /   469)	REC LOSS:	26.112	KL LOSS:	9.741
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	27.433	KL LOSS:	9.481
# TRAINING BATCH:	(  410 /   469)	REC LOSS:	22.921	KL LOSS:	9.401
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	24.320	KL LOSS:	9.447
# TRAINING BATCH:	(  440 /   469)	REC LOSS:	26.958	KL LOSS:	9.824
# TRAINING BATCH:	(  450 /   469)	REC LOSS:	24.924	KL LOSS:	9.400
# EPOCH:	   11	TRAIN LOSS:	35.063	KL WEIGHT:	1.00
# TRAINING BATCH:	(    0 /   469)	REC LOSS:	23.050	KL LOSS:	9.256
# TRAINING BATCH:	(   20 /   469)	REC LOSS:	25.194	KL LOSS:	9.197
# TRAINING BATCH:	(   40 /   469)	REC LOSS:	25.235	KL LOSS:	9.322
# TRAINING BATCH:	(   60 /   469)	REC LOSS:	25.304	KL LOSS:	9.474
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	24.672	KL LOSS:	9.584
# TRAINING BATCH:	(   80 /   469)	REC LOSS:	24.615	KL LOSS:	9.314
# TRAINING BATCH:	(  100 /   469)	REC LOSS:	24.158	KL LOSS:	9.602
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	27.885	KL LOSS:	9.528
# TRAINING BATCH:	(  120 /   469)	REC LOSS:	24.328	KL LOSS:	9.484
# TRAINING BATCH:	(  130 /   469)	REC LOSS:	25.484	KL LOSS:	9.799
# TRAINING BATCH:	(  140 /   469)	REC LOSS:	25.360	KL LOSS:	9.639
# TRAINING BATCH:	(  150 /   469)	REC LOSS:	25.367	KL LOSS:	9.326
# TRAINING BATCH:	(  160 /   469)	REC LOSS:	25.783	KL LOSS:	10.343
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	26.090	KL LOSS:	9.679
# TRAINING BATCH:	(  180 /   469)	REC LOSS:	24.225	KL LOSS:	9.797
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	24.178	KL LOSS:	9.418
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	23.107	KL LOSS:	9.804
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	24.295	KL LOSS:	9.225
# TRAINING BATCH:	(  220 /   469)	REC LOSS:	24.092	KL LOSS:	9.703
# TRAINING BATCH:	(  240 /   469)	REC LOSS:	24.486	KL LOSS:	9.866
# TRAINING BATCH:	(  260 /   469)	REC LOSS:	24.914	KL LOSS:	9.810
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	25.715	KL LOSS:	9.746
# TRAINING BATCH:	(  300 /   469)	REC LOSS:	23.857	KL LOSS:	9.809
# TRAINING BATCH:	(  320 /   469)	REC LOSS:	25.813	KL LOSS:	9.433
# TRAINING BATCH:	(  340 /   469)	REC LOSS:	24.922	KL LOSS:	9.953
# TRAINING BATCH:	(  350 /   469)	REC LOSS:	25.065	KL LOSS:	9.235
# TRAINING BATCH:	(  360 /   469)	REC LOSS:	25.833	KL LOSS:	10.330
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	25.582	KL LOSS:	9.298
# TRAINING BATCH:	(  390 /   469)	REC LOSS:	24.826	KL LOSS:	9.675
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	24.958	KL LOSS:	9.492
# TRAINING BATCH:	(  410 /   469)	REC LOSS:	26.242	KL LOSS:	9.879
# TRAINING BATCH:	(  420 /   469)	REC LOSS:	24.599	KL LOSS:	9.734
# TRAINING BATCH:	(  430 /   469)	REC LOSS:	25.997	KL LOSS:	9.909
# TRAINING BATCH:	(  440 /   469)	REC LOSS:	25.023	KL LOSS:	9.391
# TRAINING BATCH:	(  450 /   469)	REC LOSS:	23.844	KL LOSS:	9.496
# TRAINING BATCH:	(  460 /   469)	REC LOSS:	25.376	KL LOSS:	9.406
# EPOCH:	   12	TRAIN LOSS:	34.850	KL WEIGHT:	1.00
# TRAINING BATCH:	(    0 /   469)	REC LOSS:	25.271	KL LOSS:	9.889
# TRAINING BATCH:	(   10 /   469)	REC LOSS:	24.880	KL LOSS:	9.777
# TRAINING BATCH:	(   20 /   469)	REC LOSS:	25.653	KL LOSS:	9.636
# TRAINING BATCH:	(   40 /   469)	REC LOSS:	26.168	KL LOSS:	9.751
# TRAINING BATCH:	(   60 /   469)	REC LOSS:	24.907	KL LOSS:	9.559
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	22.843	KL LOSS:	9.378
# TRAINING BATCH:	(   80 /   469)	REC LOSS:	25.571	KL LOSS:	9.826
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	25.736	KL LOSS:	9.622
# TRAINING BATCH:	(  100 /   469)	REC LOSS:	24.583	KL LOSS:	9.867
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	25.464	KL LOSS:	9.785
# TRAINING BATCH:	(  120 /   469)	REC LOSS:	26.647	KL LOSS:	9.295
# TRAINING BATCH:	(  130 /   469)	REC LOSS:	25.352	KL LOSS:	9.975
# TRAINING BATCH:	(  140 /   469)	REC LOSS:	26.394	KL LOSS:	9.489
# TRAINING BATCH:	(  160 /   469)	REC LOSS:	24.718	KL LOSS:	9.421
# TRAINING BATCH:	(  180 /   469)	REC LOSS:	27.041	KL LOSS:	9.498
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	26.249	KL LOSS:	9.940
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	25.271	KL LOSS:	9.803
# TRAINING BATCH:	(  220 /   469)	REC LOSS:	24.196	KL LOSS:	9.262
# TRAINING BATCH:	(  240 /   469)	REC LOSS:	25.358	KL LOSS:	9.651
# TRAINING BATCH:	(  260 /   469)	REC LOSS:	25.617	KL LOSS:	9.704
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	25.218	KL LOSS:	9.893
# TRAINING BATCH:	(  300 /   469)	REC LOSS:	23.446	KL LOSS:	9.544
# TRAINING BATCH:	(  320 /   469)	REC LOSS:	24.871	KL LOSS:	9.998
# TRAINING BATCH:	(  340 /   469)	REC LOSS:	25.452	KL LOSS:	9.960
# TRAINING BATCH:	(  360 /   469)	REC LOSS:	24.730	KL LOSS:	9.718
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	24.127	KL LOSS:	9.389
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	24.031	KL LOSS:	10.019
# TRAINING BATCH:	(  420 /   469)	REC LOSS:	24.457	KL LOSS:	9.520
# TRAINING BATCH:	(  440 /   469)	REC LOSS:	23.539	KL LOSS:	9.682
# TRAINING BATCH:	(  460 /   469)	REC LOSS:	22.518	KL LOSS:	9.856
# EPOCH:	   13	TRAIN LOSS:	34.702	KL WEIGHT:	1.00
# TRAINING BATCH:	(   10 /   469)	REC LOSS:	25.859	KL LOSS:	9.877
# TRAINING BATCH:	(   30 /   469)	REC LOSS:	24.737	KL LOSS:	10.085
# TRAINING BATCH:	(   50 /   469)	REC LOSS:	23.626	KL LOSS:	10.172
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	25.588	KL LOSS:	9.663
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	24.653	KL LOSS:	10.338
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	24.761	KL LOSS:	9.276
# TRAINING BATCH:	(  130 /   469)	REC LOSS:	24.668	KL LOSS:	9.946
# TRAINING BATCH:	(  150 /   469)	REC LOSS:	27.173	KL LOSS:	9.763
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	26.795	KL LOSS:	9.587
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	25.004	KL LOSS:	9.906
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	24.352	KL LOSS:	9.650
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	24.317	KL LOSS:	10.259
# TRAINING BATCH:	(  230 /   469)	REC LOSS:	24.417	KL LOSS:	9.359
# TRAINING BATCH:	(  250 /   469)	REC LOSS:	26.077	KL LOSS:	9.943
# TRAINING BATCH:	(  270 /   469)	REC LOSS:	23.734	KL LOSS:	9.487
# TRAINING BATCH:	(  290 /   469)	REC LOSS:	24.269	KL LOSS:	9.570
# TRAINING BATCH:	(  310 /   469)	REC LOSS:	25.510	KL LOSS:	9.755
# TRAINING BATCH:	(  330 /   469)	REC LOSS:	24.406	KL LOSS:	9.863
# TRAINING BATCH:	(  350 /   469)	REC LOSS:	23.259	KL LOSS:	9.772
# TRAINING BATCH:	(  360 /   469)	REC LOSS:	24.286	KL LOSS:	9.961
# TRAINING BATCH:	(  370 /   469)	REC LOSS:	24.744	KL LOSS:	9.913
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	25.073	KL LOSS:	9.502
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	23.243	KL LOSS:	9.586
# TRAINING BATCH:	(  420 /   469)	REC LOSS:	25.620	KL LOSS:	9.778
# TRAINING BATCH:	(  440 /   469)	REC LOSS:	25.977	KL LOSS:	9.813
# TRAINING BATCH:	(  460 /   469)	REC LOSS:	25.557	KL LOSS:	9.762
# EPOCH:	   14	TRAIN LOSS:	34.509	KL WEIGHT:	1.00
# TRAINING BATCH:	(   10 /   469)	REC LOSS:	23.234	KL LOSS:	9.964
# TRAINING BATCH:	(   30 /   469)	REC LOSS:	23.772	KL LOSS:	9.691
# TRAINING BATCH:	(   50 /   469)	REC LOSS:	24.925	KL LOSS:	9.641
# TRAINING BATCH:	(   70 /   469)	REC LOSS:	23.934	KL LOSS:	9.599
# TRAINING BATCH:	(   80 /   469)	REC LOSS:	24.391	KL LOSS:	9.570
# TRAINING BATCH:	(   90 /   469)	REC LOSS:	24.628	KL LOSS:	9.579
# TRAINING BATCH:	(  100 /   469)	REC LOSS:	23.652	KL LOSS:	9.846
# TRAINING BATCH:	(  110 /   469)	REC LOSS:	23.291	KL LOSS:	9.923
# TRAINING BATCH:	(  120 /   469)	REC LOSS:	23.529	KL LOSS:	9.515
# TRAINING BATCH:	(  130 /   469)	REC LOSS:	25.270	KL LOSS:	9.846
# TRAINING BATCH:	(  140 /   469)	REC LOSS:	26.671	KL LOSS:	9.344
# TRAINING BATCH:	(  150 /   469)	REC LOSS:	24.885	KL LOSS:	10.054
# TRAINING BATCH:	(  170 /   469)	REC LOSS:	23.641	KL LOSS:	9.130
# TRAINING BATCH:	(  180 /   469)	REC LOSS:	25.277	KL LOSS:	10.285
# TRAINING BATCH:	(  190 /   469)	REC LOSS:	26.496	KL LOSS:	9.895
# TRAINING BATCH:	(  200 /   469)	REC LOSS:	23.433	KL LOSS:	9.657
# TRAINING BATCH:	(  210 /   469)	REC LOSS:	26.215	KL LOSS:	9.774
# TRAINING BATCH:	(  220 /   469)	REC LOSS:	22.533	KL LOSS:	9.631
# TRAINING BATCH:	(  240 /   469)	REC LOSS:	23.821	KL LOSS:	10.045
# TRAINING BATCH:	(  260 /   469)	REC LOSS:	23.977	KL LOSS:	9.934
# TRAINING BATCH:	(  280 /   469)	REC LOSS:	25.498	KL LOSS:	9.589
# TRAINING BATCH:	(  290 /   469)	REC LOSS:	23.454	KL LOSS:	9.782
# TRAINING BATCH:	(  300 /   469)	REC LOSS:	24.883	KL LOSS:	9.613
# TRAINING BATCH:	(  320 /   469)	REC LOSS:	25.217	KL LOSS:	9.870
# TRAINING BATCH:	(  340 /   469)	REC LOSS:	25.954	KL LOSS:	9.948
# TRAINING BATCH:	(  360 /   469)	REC LOSS:	23.498	KL LOSS:	9.318
# TRAINING BATCH:	(  380 /   469)	REC LOSS:	24.615	KL LOSS:	9.621
# TRAINING BATCH:	(  400 /   469)	REC LOSS:	24.023	KL LOSS:	9.694
# TRAINING BATCH:	(  420 /   469)	REC LOSS:	24.612	KL LOSS:	9.733
# TRAINING BATCH:	(  440 /   469)	REC LOSS:	24.675	KL LOSS:	9.954
# TRAINING BATCH:	(  460 /   469)	REC LOSS:	23.935	KL LOSS:	10.059
# EPOCH:	   15	TRAIN LOSS:	34.388	KL WEIGHT:	1.00

# %%
plot_reconstruction_grid(vae, train_x)

# %% [markdown]
# It seems like we don't suffer from posterior collaps and our reconstructions look rather
# good. It has been shown, that choosing KL weights larger than one can lead to overall
# better representations with the downside of worse reconstructions. This framework is
# found in literatures as $\beta$-VAE. The correct choice of the KL weight is a difficult
# one and depends on the distribution of your dataset and also its dimensionality.
#
# With a VAE we also have a generative model. We could e.g. sample zs from a uniform range
# and see what the generator will reconstruct:

# %%
rand_z = torch.rand((100, latent_size), device=vae.device)
generated_samples = vae.reconstruct(rand_z).view(100, 1, 28, 28).detach().cpu()

image_grid = make_grid(generated_samples, nrow=25)
plt.imshow(image_grid.permute(1, 2, 0))
plt.axis('off')
plt.show()

# %% [markdown]
# We can also use the generative decoder to smoothly interpolate between random samples:
# (Execute the cell a few times to see the interpolation between other random digits)

# %%
def interpolate_linear(x: Tensor, y: Tensor, steps: int,) -> Tensor:
    cur_weight = 0.0
    weight_incr = 1 / (steps - 1)

    result = torch.zeros((steps, *x.shape))
    if x.is_cuda:
        result = result.cuda()

    for step in range(steps):
        result[step] = torch.lerp(x, y, cur_weight)
        cur_weight += weight_incr

    return result

x_one = train_x.data[torch.randint(0, 60000, (1,))] / 255.
z_one = vae.encode(x_one.view(1, -1).to(vae.device))

x_two = train_x.data[torch.randint(0, 60000, (1,))] / 255.
z_two = vae.encode(x_two.view(1, -1).to(vae.device))

zs = interpolate_linear(z_one, z_two, steps=20)
x_hats = vae.reconstruct(zs).view(20, 1, 28, 28).detach().cpu()

image_grid = make_grid(x_hats, nrow=20)
plt.imshow(image_grid.permute(1, 2, 0))
plt.axis('off')
plt.show()
